# %% [markdown]
# # Virtual Research Supervisor

# %% [markdown]
# ## Foundation and basic implementation

# %%
# !pip install openai==2.28.0

# %%
import os
from dotenv import load_dotenv
from IPython.display import display, Markdown
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

# Check the key
if not api_key:
    raise ValueError("OPENAI_API_KEY environment variable is not set.")
else:
    print("API key loaded successfully.")
# Out:
# API key loaded successfully.

# %%
message = "Write a haiku about Quantum Key Distribution"

messages = [{"role": "user", "content": message}]
messages
# Out:
# [{'role': 'user', 'content': 'Write a haiku about Quantum Key Distribution'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

response.choices[0].message.content
# Out:
# 'In quantum dance spins,  \nKeys whispered through tangled light—  \nSecrets safe in code.'

# %% [markdown]
# ### Types of prompt

# %%
system_prompt = "You are a helfull assistent who explains in tamil."

# %%
user_prompt = "What is quantum key distribution? in one sentence"

# %% [markdown]
# ### Messages
# The API from OpenAI expects to receive messages in a particular structure
# ```python
# [
#     {"role":"system", "content":"System message goes here"},
#     {"role":"user", "content":"user message goes here"},
# ]
# ```

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]
response = openai.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
response.choices[0].message.content
# Out:
# 'குவாண்டம் சாவி வீதிகொடுத்தல் என்பது குவாண்டம் இயாங்கிய விறு்வு மூலம் பாதுகாப்பான தகவல் பரிமாற்றத்திற்காக இரு ஒழுங்குகள் இடையே இரகசிய குறியீட்டு சாவிகளை பகிர்வதற்கான ஒரு நுட்பமாகும்.'
