# %% [markdown]
# # Virtual Research Supervisor

# %% [markdown]
# ## Foundation and basic implementation

# %%
# !pip install openai==2.28.0

# %%
import os 
from dotenv import load_dotenv
from IPython.display import display, Markdown
from openai import OpenAI

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")


if not api_key:
    raise ValueError("OPENAI_API_KEY environment variable is not set.")
else:
    print("API key loaded successfully.")
# Out:
# API key loaded successfully.

# %%
message = "How does Quantum Key Distribution work?. explan in two sentences"
messages = [{"role": "user", "content": message }]
messages
# Out:
# [{'role': 'user',
#   'content': 'How does Quantum Key Distribution work?. explan in two sentences'}]

# %%
# openai = OpenAI()

# response = openai.chat.completions.create(
#     model="gpt-4o",
#     messages=messages
# )

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

response.choices[0].message.content
# Out:
# 'Quantum Key Distribution (QKD) utilizes the principles of quantum mechanics to securely exchange cryptographic keys, primarily by encoding key information in quantum states such as photons, ensuring that any eavesdropping attempts disrupt these states and are thus detectable. Typically, schemes like the BB84 protocol use properties like polarization to transmit keys, ensuring that the key exchange remains secure from interceptors due to the no-cloning theorem of quantum mechanics.'

# %% [markdown]
# ### Types of prompt

# %%
system_prompt = "You are a helpful assistant that explains complex concepts in simple terms."

# %%
user_prompt = "What is Quantum Machine Learning? Explain me in exactly 10 words"

# %% [markdown]
# ### Messages
# The API from OpenAI expects to receive messages in a particular structure
# ```python
# [
#     {"role":"system", "content":"System message goes here"},
#     {"role":"user", "content":"user message goes here"},
# ]
# ```

# %%
messages = [{"role":"system", "content": system_prompt},
            {"role":"user", "content": user_prompt }]

response = openai.chat.completions.create(model="gpt-4o", messages=messages)
response.choices[0].message.content
# Out:
# 'Quantum computers enhancing machine learning with faster data processing speeds.'

# %% [markdown]
# ### Chat Completions API

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY environment variable is not set.")
else:
    print("API key loaded successfully.")
# Out:
# API key loaded successfully.

# %% [markdown]
# #### Endpont

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}
payload = {
    "model": "gpt-4o",
    "messages": [
        {"role": "system", "content": "You are a helpful assistant that explains complex concepts in simple terms."},
        {"role": "user", "content": "What is Quantum Machine Learning? Explain me in exactly 10 words"}
    ]
}

payload
# Out:
# {'model': 'gpt-4o',
#  'messages': [{'role': 'system',
#    'content': 'You are a helpful assistant that explains complex concepts in simple terms.'},
#   {'role': 'user',
#    'content': 'What is Quantum Machine Learning? Explain me in exactly 10 words'}]}

# %%
response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
response_json = response.json()

# %%
response_json
# Out:
# {'id': 'chatcmpl-DLUgxpYhqmHE0GrEMpzgJFTdMwDO9',
#  'object': 'chat.completion',
#  'created': 1774015239,
#  'model': 'gpt-4o-2024-08-06',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'Combines quantum computing and machine learning for enhanced data processing.',
#     'refusal': None,
#     'annotations': []},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 37,
#   'completion_tokens': 12,
#   'total_tokens': 49,
#   'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#   'completion_tokens_details': {'reasoning_tokens': 0,
#    'audio_tokens': 0,
#    'accepted_prediction_tokens': 0,
#    'rejected_prediction_tokens': 0}},
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_e578fe32d1'}

# %%
response_json["choices"][0]["message"]["content"]
# Out:
# 'Combines quantum computing and machine learning for enhanced data processing.'

# %% [markdown]
# #### OpenAI Client

# %%
# reate OpenAI client 
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant that explains complex concepts in funny way."},
        {"role": "user", "content": "What is Quantum Machine Learning? Explain me in exactly 10 words"}
    ]
)
response.choices[0].message.content
# Out:
# 'Quantum computers enhancing AI with speed by exploiting quantum mechanics.'

# %%
load_dotenv()
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

google_api_key = os.getenv("GOOGLE_API_KEY")
if not google_api_key:
    raise ValueError("GOOGLE_API_KEY environment variable is not set.")
else:
    print("Google API key loaded successfully.")
# Out:
# Google API key loaded successfully.

# %%
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

# %%
response = gemini.chat.completions.create(
    model="gemini-2.5-pro",
    messages=[
        {"role": "system", "content": "You are a helpful assistant that explains complex concepts in funny way."},
        {"role": "user", "content": "What is Quantum Machine Learning? Explain me in exactly 10 words"}
    ]
)
response.choices[0].message.content
# Out:
# "Using reality's cheat codes to make your computer learn faster."

# %% [markdown]
# #### Ollama Endpont

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama" )

# %%
response = ollama.chat.completions.create(
    model="gpt-oss:20b-cloud",
    messages=[
        {"role": "system", "content": "You are a helpful assistant that explains complex concepts in funny way."},
        {"role": "user", "content": "What is Quantum Machine Learning? Explain me in exactly 10 words"}
    ]
)
response.choices[0].message.content
# Out:
# 'Quantum machine learning: brains meet qubits, weirdly smarter, unpredictably hilarious.'

# %% [markdown]
# #### Tokenizing with code

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
import tiktoken

# %%
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("Geometry is the branch of mathematics that studies shapes, sizes, and properties of space.")

# %%
tokens
# Out:
# [30417,
#  382,
#  290,
#  14338,
#  328,
#  49085,
#  484,
#  11227,
#  29447,
#  11,
#  16174,
#  11,
#  326,
#  8359,
#  328,
#  4918,
#  13]

# %%
for token in tokens:
    token_text = encoding.decode([token])
    print(f"Token ID: {token}, Token Text: '{token_text}'")
# Out:
# Token ID: 30417, Token Text: 'Geometry'
# Token ID: 382, Token Text: ' is'
# Token ID: 290, Token Text: ' the'
# Token ID: 14338, Token Text: ' branch'
# Token ID: 328, Token Text: ' of'
# Token ID: 49085, Token Text: ' mathematics'
# Token ID: 484, Token Text: ' that'
# Token ID: 11227, Token Text: ' studies'
# Token ID: 29447, Token Text: ' shapes'
# Token ID: 11, Token Text: ','
# Token ID: 16174, Token Text: ' sizes'
# Token ID: 11, Token Text: ','
# Token ID: 326, Token Text: ' and'
# Token ID: 8359, Token Text: ' properties'
# Token ID: 328, Token Text: ' of'
# Token ID: 4918, Token Text: ' space'
# Token ID: 13, Token Text: '.'

# %% [markdown]
# ### Message History

# %%
openai = OpenAI()

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant that explains complex concepts in funny way."},
    {"role": "user", "content": "Hi Im Jegan"}
]

# %%
response = openai.chat.completions.create(model="gpt-4o", messages=messages)
response.choices[0].message.content
# Out:
# "Hi Jegan! I'm your friendly assistant, here to explain things with a pinch of humor. What can I do for you today? Ready to dive into the fun world of knowledge or just need help finding your keys? (Unfortunately, I can't actually find your keys, but I can tell you all about how to make a device to find them!)"

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant that explains complex concepts in funny way."},
    {"role": "user", "content": "Whats my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-4o", messages=messages)
response.choices[0].message.content
# Out:
# 'I don\'t know your name, but I could try guessing! Are you someone with a name that\'s alphabetical, numerical, or just plain magical? Or is it something fun and unexpected like "Admiral Pineapple" or "Captain Cookie"? Either way, nice to meet you!'

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant that explains complex concepts in funny way."},
    {"role": "user", "content": "Hi my name is Jegan"},
    {"role": "assistant", "content": "Hi Jegan! I'm your friendly assistant, here to explain things with a pinch of humor. What can I do for you today? Ready to dive into the fun world of knowledge or just need help finding your keys? (Unfortunately, I can't actually find your keys, but I can tell you all about how to make a device to find them!)",},
    {"role": "user", "content": "Whats my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-4o", messages=messages)
response.choices[0].message.content
# Out:
# "Your name is Jegan! Don't worry; I haven't forgotten (yet). I'm like an elephant when it comes to remembering names, but way less wrinkly. Need help with anything else, Jegan?"
